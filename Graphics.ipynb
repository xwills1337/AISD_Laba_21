# %%
import matplotlib.pyplot  as plt 
import pandas as pd

# %%
fill= pd.Series({1000:0.000567688, 10000:0.0126016,100000:0.0912311})
plt.plot(fill)
plt.title("Заполнение")
plt.show()

# %%
search= pd.Series({1000:0.0000001441, 10000:0.0000002501,100000:0.0000006059})
plt.title("Поиск")
plt.plot(search)
plt.show()

# %%
addition= pd.Series({1000:0.0000003602 , 10000:0.0000004752,100000:0.0000006762})
plt.plot(addition)
plt.title("Добавление")
plt.show()

# %%
deleting= pd.Series({1000:0.0000001935 , 10000:0.0000002644,100000:0.0000005752})
plt.plot(deleting)
plt.title("Удаление")
plt.show()
